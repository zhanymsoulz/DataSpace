# %%
import pandas as pd
import yaml
import xml.etree.ElementTree as ET

# %%
# Load CSV
medical = pd.read_csv('2014_medical.csv')

# %%
# Load XML
tree = ET.parse('exercise.xml')
root = tree.getroot()
exercise_rows = []
for patient in root.findall('patient'):
    row = {**patient.attrib}
    for child in patient:
        row[child.tag] = child.text
    exercise_rows.append(row)
exercise = pd.DataFrame(exercise_rows)

# %%
# Load YAML
with open('insurance.yaml') as f:
    insurance_data = yaml.safe_load(f)
insurance = pd.DataFrame(insurance_data)

# %%
# Join medical and exercise on patient_id/id
merged = pd.merge(medical, exercise, left_on='patient_id', right_on='id', how='left', suffixes=('', '_exercise'))

# %%
print(merged.head(10))
# Out:
#          date  hour patient_id gender     condition  heart_rate  \
# 0  2014-01-01     0       P001      M     Pneumonia          78
# 1  2014-01-01     1       P002      F  Hypertension          85
# 2  2014-01-01     2       P003      F  Post-surgery          92
# 3  2014-01-01     3       P001      M     Pneumonia          75
# 4  2014-01-01     4       P002      F  Hypertension          82
# 5  2014-01-01     5       P003      F  Post-surgery       -9999
# 6  2014-01-01     6       P001      M           NaN          76
# 7  2014-01-01     7       P002      F  Hypertension          80
# 8  2014-01-01     8       P003      F  Post-surgery          88
# 9  2014-01-01     9       P001      M     Pneumonia          77
#
#    blood_pressure_systolic  blood_pressure_diastolic  oxygen_saturation  \
# 0                      120                        80                 95
# 1                      140                        90                 98
# 2                      125                        85              -9999
# 3                      118                        79                 96
# 4                      138                        88                 97
# 5                      123                        82                 95
# 6                      117                        78                 96
# 7                      135                        87                 98
# 8                      121                        80                 94
# 9                      119                        81                 95
#
#    temperature    medication medication_dose    outcome    id disease_id  \
# 0         37.5    Antibiotic           500mg     Stable  P001      DI001
# 1         36.9  Beta-blocker            50mg  Improving  P002      DI002
# 2         37.8           NaN           100mg   Critical  P003      DI001
# 3         37.2    Antibiotic           500mg        NaN  P001      DI001
# 4         36.8  Beta-blocker             NaN  Improving  P002      DI002
# 5         37.5     Analgesic           100mg   Critical  P003      DI001
# 6         37.0    Antibiotic           500mg  Improving  P001      DI001
# 7         36.7           NaN            50mg  Improving  P002      DI002
# 8         37.6     Analgesic           100mg   Critical  P003      DI001
# 9         37.4    Antibiotic           500mg     Stable  P001      DI001
#
#   morning afternoon evening
# 0      30        20      15
# 1      25        10      20
# 2      40         0      30
# 3      30        20      15
# 4      25        10      20
# 5      40         0      30
# 6      30        20      15
# 7      25        10      20
# 8      40         0      30
# 9      30        20      15

# %%
merged.to_csv('01_temp.csv', index=False)
